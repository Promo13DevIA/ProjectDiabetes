# %% [markdown]
# # <center><font color=purple>Projet diabète</font></center>
#
# <font><a id='synopsis'></a><b>Synopsis :</b></font>
# Les Pimas sont un peuple de Nord-Amérindiens originaires du Mexique et du Sonora.
#
# Le peuple Pima est connu pour être une des communautés comportant le plus grand pourcentage d'obèses et de diabétiques au monde, et à ce titre ils sont un sujet d'études pour les scientifiques ; en effet, alors qu'ils partagent un patrimoine génétique commun, les Pimas mexicains ont rarement ces deux pathologies qui semblent propres aux Pimas d'Arizona et directement en rapport avec leur mode de vie.
# ![image.png](attachment:image.png)

# %% [markdown]
# Cet ensemble de données est à l'origine de l'Institut national du diabète et des maladies digestives et rénales.
# Il est fourni avec l'aimable autorisation de la base de données sur le diabète des Indiens Pima et est disponible sur Kaggle:
# Il se compose de plusieurs mesures médicales et d'un diagnostic (la variable à prévoir).
#
# L'ensemble de données comporte 9 colonnes, comme indiqué ci-dessous;
#
#  <a id="data"></a>
# **Contenu**
# Les ensembles de données se compose de plusieurs variables prédictives médical et une variable cible, ***Outcome*** . Les variables prédictives comprennent :
#  - 1) le nombre de grossesses de la patiente
#  - 2) le taux de glucose (mg/dl)
#  - 3) la pression sanguine (mm Hg)
#  - 4) épaisseur du pli cutané du triceps (mm)
#  - 5) son IMC (poids en kg / (taille en m)²)
#  - 6) son taux d'insuline (µUI/mL)
#  - 7) les antécédent familiaux
#  - 8) son âge (années)
#
#
# **Index**| **Nom** | **Définition** | **Libellé**
#            --|--|--|--
# `1`|`Pregnancies`|le nombre de grossesses de la patiente | *Quantité*
# `2`|`Glucose`|taux de glucose | *(mg/dl)*
# `3`|`BloodPressure`|la pression sanguine |*(mm Hg)*
# `4`|`SkinThickness`|épaisseur du pli cutané du triceps |*(mm)*
# `5`|`Insulin`|son taux d'insuline | *(µUI/mL)*
# `6`|`BMI`|son IMC  | *(poids en kg / (taille en m)²)*
# `7`|`DiabetesPedigreeFunction`|Fonction généalogique du diabète | *(valeur conventionnelle)*
# `8`|`Age`|son âge  | *(années)*
# **`Target`**|**`Outcome`**|**0 = Sain, 1 = Diabétique**  | ***catégorie***
#
# Énoncé du problème
#
# Il s'agit d'un problème de classification à l'aide de l'apprentissage automatique supervisé.
# L'objectif est de prédire si un patient est diabétique ou non, sur la base de certaines mesures diagnostiques incluses dans l'ensemble de données.
#
# Dans ce projet, nous utilisons python3 et le notebook Jupyter.
# Nous allons parcourir le projet en important l'ensemble de données, en effectuant une analyse exploratoire des données pour obtenir des informations et comprendre à quoi ressemble l'ensemble de données, puis construire le modèle.
#
# Les 7 étapes de l'apprentissage automatique:
#
#     Collecte de données
#     Préparation des données
#     Choisir un modèle
#     Entraîner le modèle
#     Évaluer le modèle
#     Réglage des paramètres
#     Faire des prédictions
#
# Commençons donc par importer les bibliothèques requises.
# Nous importons des bibliothèques d'analyse de données (`pandas`, `numpy`) et des bibliothèques de visualisation (`matplotlib`, `seaborn`).
#
# Pour résoudre le problème, nous devrons analyser les données, effectuer toute les transformations et normalisations requises, appliquer un algorithme d'apprentissage automatique, entraîner un modèle, vérifier les performances du modèle entraîné et itérer avec d'autres algorithmes jusqu'à ce que nous trouvions le plus performant pour notre type. de l'ensemble de données.

# %% [markdown]
# Sources liées :
# *Kaggle  Pima Indians Diabetes Database*
# https://www.kaggle.com/uciml/pima-indians-diabetes-database
#
# *Exemple de compréhension de données*
# https://medium.com/datadriveninvestor/exploratory-data-analysis-on-diabeties-dataset-b172589e3a1c
#
# *Hardrop, autorisé quand cela concerne moins de 5% des données*
# http://sigmaquality.pl/uncategorized/initial-graphical-analysis-of-dependency-in-analyzing-of-the-incidence-of-diabetes-seaborn-library/

# %% [markdown]
# <a id='imports'></a>

# %%
# importer les librairies 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
_fontdict={'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }

# %%
def display_side_by_side(*args):
    """
    display dataframes in row
    """
    from IPython.display import display_html
    html_str=''
    for df in args:
        type(df)
        if type(df) == pd.core.frame.DataFrame :
            html_str+=df.to_html()
        elif type (df) == pd.io.formats.style.Styler :
            html_str+=df.render()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True); del display_html

# %% [markdown]
# ### EDA <a id='EDA'></a>

# %%
# importer la base de données
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# vérifier les valeurs null
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# voir la description du dataset
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# voir les informations sur le dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#Visuel sur la variable 'Outcome' (diabétique=1 ; NON diabétiques=0)
sns.countplot(df['Outcome'])

# %%
# Création d'une corrélation entre les différents features
plt.figure(figsize=(20,10))
sns.heatmap (df.corr(), annot = True)

# %%
#Recherche des valeurs 0 dans les différentes colonnes
print("\033[1mNombre de valeurs nulles par colonne:\033[0;0m")
count = 0
while (count <= len(df.columns)-2):
    print(f"{df.columns[count]:-<30}{format(len(df.loc[df.iloc[:,count]== 0]))}") 
    count = count + 1
temp = "Total :"
print(f"{temp:-<30}\033[1m{len(df)}\033[0;0m")
del temp
# Out:
# Nombre de valeurs nulles par colonne:
# Pregnancies-------------------111
# Glucose-----------------------5
# BloodPressure-----------------35
# SkinThickness-----------------227
# Insulin-----------------------374
# BMI---------------------------11
# DiabetesPedigreeFunction------0
# Age---------------------------0
# Total :-----------------------768

# %% [markdown]
# _____

# %% [markdown]
# <a id='null'></a>
# #### <center>Etude en supprimant les valeurs à 0 et par la médiane</center>

# %% [markdown]
# Pas besoin de faire une copy, on importe directement le résultat dans un nouveau df
# ```python
# df_clean = df.copy()
# df_median = df.copy()
# col = ["BMI", "Glucose", "SkinThickness", "Insulin"]
# for i in col :
#     df_clean = df_clean[df_clean[i] != 0] #non égale 0
#     df_median[i]  =  df_median[i].replace(to_replace = 0,  value = df_median[i].median())
# df_clean , df_median```

# %%
col = ["BMI", "Glucose", "SkinThickness", "Insulin"] # Les autres colones peuvent avoir des valeurs nulles.
for i in col :
    df_clean = df[df[i] != 0] # Supprime les valeurs nulles
    df_median[i]  =  df[i].replace(to_replace = 0,  value = df[i].median())
display_side_by_side(df_median.head(), df_clean.head());
print("median shape\n",df_median.shape,"\nhard_drop shape\n",df_clean.shape)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Pregnancies</th>
#       <th>Glucose</th>
#       <th>BloodPressure</th>
#       <th>SkinThickness</th>
#       <th>Insulin</th>
#       <th>BMI</th>
#       <th>DiabetesPedigreeFunction</th>
#       <th>Age</th>
#       <th>Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6</td>
#       <td>148</td>
#       <td>72</td>
#       <td>35</td>
#       <td>30.5</td>
#       <td>33.6</td>
#       <td>0.627</td>
#       <td>50</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>85</td>
#       <td>66</td>
#       <td>29</td>
#       <td>30.5</td>
#       <td>26.6</td>
#       <td>0.351</td>
#       <td>31</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>183</td>
#       <td>64</td>
#       <td>23</td>
# ...

# %%
sns.countplot(data=df_clean, x="Outcome")
plt.title("Proportion des targets avec le hard drop", fontdict=_fontdict)
plt.show()

# %%
df_clean.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   394.000000  394.000000     394.000000     394.000000  394.000000
# mean      3.286802  122.304569      70.654822      29.106599  155.548223
# std       3.209635   31.396725      12.469919      10.504273  118.775855
# min       0.000000    0.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      62.000000      21.000000   76.250000
# 50%       2.000000  119.000000      70.000000      29.000000  125.000000
# 75%       5.000000  143.000000      78.000000      36.750000  190.000000
# max      17.000000  198.000000     110.000000      63.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  394.000000                394.000000  394.000000  394.000000
# mean    32.988579                  0.525543   30.814721    0.329949
# std      7.210160                  0.350127   10.198971    0.470792
# ...

# %% [markdown]
# ______

# %% [markdown]
# <a id='viz'></a>
# #### <center>Visualisation sur df_clean (Hard drop)</center>

# %%
columns = ["Pregnancies",  "Glucose",  "BloodPressure",  "SkinThickness",  "Insulin", "BMI", "DiabetesPedigreeFunction",  "Age"]
def tripleviz(dataframe):
    for col in dataframe[columns]:   


        mu = dataframe[col].mean()
        median = np.median(dataframe[col])
        sigma = dataframe[col].std()
        name = dataframe[col].name

        fig = plt.figure()

        fig.suptitle('Visualisation et analyse de la colonne '+ name , fontsize=14, fontweight='bold')

        ax = fig.add_subplot(133)
        fig.subplots_adjust(top=0.85)
        ax.text(2, 8, 'Les chiffres clés', style='italic',
                bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})


        ax.text(2, 6, r'$\mu=%.2f$' % (mu, ), fontsize=15)
        ax.text(2, 4, r'$\mathrm{median}=%.2f$' % (median, ), fontsize=15)
        ax.text(2, 2, r'$\sigma=%.2f$' % (sigma, ), fontsize=15)

        ax.axis([0, 10, 0, 10])



        plt.subplot(131), sns.distplot(dataframe[col])
        plt.subplot(132), dataframe[col].plot.box(figsize=(16,5))




        plt.show()

# %%
tripleviz(df_clean)

# %%
def viz_output(dataframe):


    df_positif = dataframe[dataframe['Outcome']==1]
    df_negatif = dataframe[dataframe['Outcome']==0]

    for col in df_clean :
        plt.figure()
        sns.distplot(df_positif[col], label='positif')
        sns.distplot(df_negatif[col], label='negatif')
        plt.legend()

# %%
viz_output(df_clean)
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\utilisateur\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(16,6))
plt.subplot(), sns.countplot(x= 'Age', hue= 'Outcome', data=df_clean)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x25f3abfd588>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25f3abfd588>)

# %% [markdown]
# ________

# %% [markdown]
# <a id='vizmedian'></a>
# #### <center>Visualisation sur df_median</center>

# %%
tripleviz(df_median)

# %%
viz_output(df_median)
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\utilisateur\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(16,6))
plt.subplot(), sns.countplot(x= 'Age', hue= 'Outcome', data=df_median)
plt.show()

# %% [markdown]
# ___________

# %% [markdown]
# <a id=modele></a>
# #### <center>Etude Machine Learning </center>

# %% [markdown]
# Sélection du modèle
#
# La phase de sélection des modèles ou des algorithmes est la plus passionnante et le cœur de l'apprentissage machine. C'est la phase où nous sélectionnons le modèle le plus performant pour l'ensemble des données dont nous disposons.
#
# Tout d'abord, nous allons calculer la "précision de la classification (précision des tests)" d'un ensemble donné de modèles de classification avec leurs paramètres par défaut afin de déterminer quel modèle est le plus performant avec l'ensemble de données sur le diabète.
#
# Nous importerons les bibliothèques nécessaires
# Nous importerons `train_test_split` pour la division train/test et
# `cross_val_score` pour la validation croisée k-fold.
# `accuracy_score` permet d'évaluer la précision du modèle dans la méthode de fractionnement train/test.

# %% [markdown]
# Nous utiliserons les classifieurs suivant :
# - RandomForestClassifier
# - DecisionTreeClassifier
# - XGBClassifier

# %%
sns.pairplot(df_clean, corner=True, hue='Outcome')
plt.show()

# %% [markdown]
# <a id='importsmodel'></a>

# %% [markdown]
# pip install xgboost

# %%
#Importation des différentes librairies
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score as score
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix, classification_report

# %% [markdown]
# Nous allons initialiser les modèles de classificateurs avec leurs paramètres par défaut et les ajouter à une liste de modèles.

# %%
#Préparer un tableau avec tous les algorithmesmodels

# %%
def data_target(dataframe, dict_result, models):
    
    counter = 0

    for i in models:
        
        X = dataframe.iloc[:, 0: -1]
        y = dataframe.iloc[:, -1]

        X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state = 0)

        i.fit(X_train, y_train)
        y_pred = i.predict(X_test)

        y.replace([0, 1], ["Non Diabètique","Diabètique"])
        
        print ("\n\n", '≡'*18, "Etude diabète avec model : ",i.__class__.__name__, '≡'*18, "\n")
        report = classification_report(y_test, y_pred)
        print(report)

        dict_result.append(report)
        
        
    
        feature_imp = pd.Series(i.feature_importances_,index=X.columns).sort_values(ascending=False)
        print(feature_imp)

        sns.barplot(x=feature_imp, y=feature_imp.index)
        plt.xlabel('Feature Importance Score')
        plt.ylabel('Features')
        plt.title("Visualizing Important Features")
        plt.legend()
        plt.show()
              
        plot_confusion_matrix(i, X_test, y_test)
        plt.show()
        
        counter +=1

# %%
models = [ RandomForestClassifier(), DecisionTreeClassifier(criterion = 'gini', random_state = 0,max_depth=5), XGBClassifier()]
dic_resultats = []
data_target(df_median, dic_resultats, models)
# Out:
# No handles with labels found to put in legend.
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡ Etude diabète avec model :  RandomForestClassifier ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
#                 precision    recall  f1-score   support
#
#     Diabètique       0.71      0.72      0.72        47
# Non Diabètique       0.88      0.87      0.87       107
#
#       accuracy                           0.82       154
#      macro avg       0.79      0.80      0.79       154
#   weighted avg       0.83      0.82      0.83       154
#
# Glucose                     0.249050
# BMI                         0.164630
# Age                         0.144767
# DiabetesPedigreeFunction    0.125649
# BloodPressure               0.090352
# Insulin                     0.078247
# Pregnancies                 0.078093
# SkinThickness               0.069212
# dtype: float64
# No handles with labels found to put in legend.
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡ Etude diabète avec model :  DecisionTreeClassifier ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
# ...

# %% [markdown]
# <a id='scores'></a>

# %%
i = 0
while(i <= len(models)-1):
    print("\n\n", '≡'*18, "Etude diabète avec model : ", models[i].__class__.__name__, '≡'*18, "\n")
    print(dic_resultats[i])
    i +=1
# Out:
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡ Etude diabète avec model :  RandomForestClassifier ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
#                 precision    recall  f1-score   support
#
#     Diabètique       0.73      0.74      0.74        47
# Non Diabètique       0.89      0.88      0.88       107
#
#       accuracy                           0.84       154
#      macro avg       0.81      0.81      0.81       154
#   weighted avg       0.84      0.84      0.84       154
#
#
#
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡ Etude diabète avec model :  DecisionTreeClassifier ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
#                 precision    recall  f1-score   support
#
#     Diabètique       0.61      0.74      0.67        47
# Non Diabètique       0.88      0.79      0.83       107
#
#       accuracy                           0.78       154
#      macro avg       0.75      0.77      0.75       154
#   weighted avg       0.80      0.78      0.78       154
#
#
#
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡ Etude diabète avec model :  XGBClassifier ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
# ...

# %% [markdown]
# <a id='pca'></a>
# ## Analyse en composantes principales
# Cette phase de l'analyse permet de mieux comprendre la structure de corrélation des variables afin de transformer des variables corrélées.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
# définition de la commande

def fit_pca(dataframe):
    
    pca = PCA()
    # Sélection des variables quantitatives
    dat=dataframe[["Pregnancies",  "Glucose",  "BloodPressure",  "SkinThickness",  "Insulin", "BMI", "DiabetesPedigreeFunction",  "Age"]]
    # réduction
    data = pd.DataFrame(scale(dat),columns=dat.columns)
    # composantes principales
    C = pca.fit(data).transform(data)
    
    
    
     # coordonnées des variables
    coord1=pca.components_[0]*np.sqrt(pca.explained_variance_[0])
    coord2=pca.components_[1]*np.sqrt(pca.explained_variance_[1])
    fig = plt.figure(figsize=(8,8))
    plt.title('Variables et cercle des corrélations', fontsize=14, fontweight='bold')
    ax = fig.add_subplot(1, 1, 1)
    for i, j, nom in zip(coord1,coord2, data.columns):
        plt.text(i, j, nom)
        plt.arrow(0,0,i,j,color='r')
    plt.axis((-1.2,1.2,-1.2,1.2))
    # cercle
    c=plt.Circle((0,0), radius=1, color='b', fill=False)
    ax.add_patch(c)
    plt.show()   
    
    
    
    from scipy.cluster.hierarchy import dendrogram, linkage
    Z = linkage(df_clean.T, 'ward')
    plt.figure(figsize=(15, 8))
    plt.title('Hierarchical Clustering Dendrogram', fontsize=14, fontweight='bold')
    plt.xlabel('Variable')
    plt.ylabel('Distance')
    dendrogram(Z,leaf_font_size=8.,labels=df_clean.columns)
    plt.show()
    
    
    plt.figure()
    plt.title('Eboulis des valeurs propres', fontsize=14, fontweight='bold')
    plt.xlabel('Variable')
    plt.plot(pca.explained_variance_ratio_)
    plt.show()
    
    
    plt.figure()
    plt.title('Diagrammes boîte des composantes principales', fontsize=14, fontweight='bold')
    plt.boxplot(C[:,0::])
    labels=df_clean.columns
    plt.show()
    
    plt.figure(figsize=(10,8))
    plt.title('Représentation des individus', fontsize=14, fontweight='bold')
    for i, j, nom in zip(C[:,0], C[:,1], dataframe['Outcome']):
        color = "red" if nom == 0 else "blue"
        plt.text(i, j, nom, color=color)
    plt.axis((-6,7.5,-5,6))  
    plt.show()

    
    
    return C

# %%
fit_pca(df_median)
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\ipykernel_launcher.py:22: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# array([[ 1.34889998, -1.07911092, -0.14504857, ..., -0.6475198 ,
#          0.77350149, -0.11526952],
#        [-1.41431717,  0.25215107, -0.62221531, ...,  0.35414651,
#          0.89605553,  0.09132194],
#        [ 0.16415601, -1.24475322,  1.58369823, ..., -1.06732842,
#         -0.09938656, -1.74343747],
#        ...,
#        [-0.68330083, -0.53836557,  0.34089287, ...,  0.37995428,
#         -0.08479013, -0.45684775],
#        [-0.57806656, -0.57700974,  0.21485697, ..., -0.8011756 ,
#          0.92102206,  0.96404906],
# ...

# %%
fit_pca(df_clean)
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\ipykernel_launcher.py:22: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# array([[-2.05907699,  0.09037908, -0.30883437, ...,  0.28726044,
#         -0.18944149, -0.05020256],
#        [ 0.78151938,  2.44246325,  2.21271813, ..., -0.41955344,
#          0.79182786,  0.8211172 ],
#        [-1.73403355,  0.17195429, -0.50574255, ...,  0.3998171 ,
#         -0.18655065,  0.02283049],
#        ...,
#        [-1.96979281,  0.31476091, -0.18944152, ..., -0.13706275,
#         -0.13033289, -0.18550571],
#        [ 2.37880523, -2.08677885, -2.00789327, ...,  0.75536069,
#         -1.05191867,  0.88310947],
# ...

# %% [markdown]
# Mise en page

# %%
# %%HTML
# <!--
# HTML and CSS code to have a navigation bar on the left and an area to write notes on the right.
# The script showthis is used to display a link in a new window.
# -->
# <style>
#     .navigation {
#         position: fixed;
#         top: 100px;
#         left: 0px;
#         background: white;
#         height: 100%;
#         width: 9%;
#         padding: 20px;
#         overflow-y:scroll;
#     }
#     .notes {
#         position: fixed;
#         top: 100px;
#         right: 0px;
#         background: white;
#         height: 100%;
#         width: 11%;
#         padding: 20px;
#         padding-bottom: 50px;
#         overflow-y:scroll;
#     }
#     .container {
#         width:80%
#     }
# </style>
# <script>
# function showthis(url) {
# 	window.open(url, "pres", "toolbar=yes,scrollbars=yes,resizable=yes,top=10,left=400,width=500,height=500");
# 	return(false);
# }
# </script>
# Out:
# <!--
# HTML and CSS code to have a navigation bar on the left and an area to write notes on the right.
# The script showthis is used to display a link in a new window.
# -->
# <style>
#     .navigation {
#         position: fixed;
#         top: 100px;
#         left: 0px;
#         background: white;
#         height: 100%;
#         width: 9%;
#         padding: 20px;
#         overflow-y:scroll;
#     }
#     .notes {
#         position: fixed;
#         top: 100px;
#         right: 0px;
#         background: white;
#         height: 100%;
#         width: 11%;
#         padding: 20px;
#         padding-bottom: 50px;
#         overflow-y:scroll;
#     }
#     .container {
#         width:80%
#     }
# </style>
# <script>
# function showthis(url) {
# 	window.open(url, "pres", "toolbar=yes,scrollbars=yes,resizable=yes,top=10,left=400,width=500,height=500");
# 	return(false);
# }
# </script>

# %% [markdown]
# <font color="orangered" size=5>Menu</font>
# <a id=menu></a>
# <div class=navigation>
#     <div>
#         <a href=https://cutt.ly/linkedin_Nicolas_Churlet onclick=return(showthis(this.href));><font color="orangered">Contact</font></a>
#     </div>
#     <div>
#         <a href="#synopsis"><font color="purple">Synopsis</font></a>
#     </div>
#     <div>
#         <a href="#data"><font color="purple">Données</font></a>
#     </div>
#     <div>
#         <br><a href="#EDA"><font color="#0000FF">EDA</font></a>
#     </div>
#     <div>
#         <a href="#null"><font color="#8800FF">Fill na</font></a>
#     </div>
#     <div>
#         <a href="#viz"><font color="#0000FF">Viz sur hard drop</font></a>
#     </div>
#     <div>
#         <a href="#vizmedian"><font color="#8800FF">Viz sur median</font></a>
#     </div>
#     <div>
#         <a href="#modele"><font color="#0000FF">Modèle</font></a>
#     </div>
#     <div>
#         <a href="#scores"><font color="#8800FF">Scores</font></a>
#     </div>
#     <div>
#         <a href="#pca"><font color="#0000FF">PCA</font></a>
#     </div>
#     <div>
#         <br><a href="#menu"><font color="#01DF74">Menu</font></a>
#     </div>
#     <div>
#         <a href="#notes"><font color="green">Notes</font></a>
#     </div>
#     <div>
#         <a href="#imports"><font color="#01DF74">Imports</font></a>
#     </div>
#     <div>
#         <a href="#importsmodel"><font color="green">Imports modèles</font></a>
#     </div>
# </div>
